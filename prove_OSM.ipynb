# %% [markdown]
# # Data Science Lab on Smart Cities
# ## Analysis of Small Commercial Activities in Milan for Smart Cities Enhancement

# %% [markdown]
# ### Open Street Map API

# %%
#!pip install overpy
#!pip install osmnx
import overpy
import osmnx as ox
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Silvia Grosso\OneDrive - Università degli Studi di Milano-Bicocca\Desktop\SMART CITIES\commercial-activities-Milan\prove.ipynb Cell 3 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Silvia%20Grosso/OneDrive%20-%20Universit%C3%A0%20degli%20Studi%20di%20Milano-Bicocca/Desktop/SMART%20CITIES/commercial-activities-Milan/prove.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> #!pip install overpy
#       <a href='vscode-notebook-cell:/c%3A/Users/Silvia%20Grosso/OneDrive%20-%20Universit%C3%A0%20degli%20Studi%20di%20Milano-Bicocca/Desktop/SMART%20CITIES/commercial-activities-Milan/prove.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> #!pip install osmnx
#       <a href='vscode-notebook-cell:/c%3A/Users/Silvia%20Grosso/OneDrive%20-%20Universit%C3%A0%20degli%20Studi%20di%20Milano-Bicocca/Desktop/SMART%20CITIES/commercial-activities-Milan/prove.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> import overpy
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Silvia%20Grosso/OneDrive%20-%20Universit%C3%A0%20degli%20Studi%20di%20Milano-Bicocca/Desktop/SMART%20CITIES/commercial-activities-Milan/prove.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> import osmnx as ox
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\osmnx\__init__.py:3, in <module>
#       1 """OSMnx init."""
# ----> 3 from ._api import *
#       4 from ._version import __version__
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\osmnx\_api.py:6, in <module>
#       4 from .bearing import orientation_entropy
#       5 from .bearing import plot_orientation
# ----> 6 from .distance import k_shortest_paths
#       7 from .distance import nearest_edges
#       8 from .distance import nearest_nodes
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\osmnx\distance.py:25, in <module>
#      23 # scikit-learn is optional dependency for unprojected nearest-neighbor search
#      24 try:
# ---> 25     from sklearn.neighbors import BallTree
#      26 except ImportError:  # pragma: no cover
#      27     BallTree = None
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\sklearn\__init__.py:82, in <module>
#      80 from . import _distributor_init  # noqa: F401
#      81 from . import __check_build  # noqa: F401
# ---> 82 from .base import clone
#      83 from .utils._show_versions import show_versions
#      85 __all__ = [
#      86     "calibration",
#      87     "cluster",
#    (...)
#     128     "show_versions",
#     129 ]
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\sklearn\base.py:17, in <module>
#      15 from . import __version__
#      16 from ._config import get_config
# ---> 17 from .utils import _IS_32BIT
#      18 from .utils._tags import (
#      19     _DEFAULT_TAGS,
#      20     _safe_tags,
#      21 )
#      22 from .utils.validation import check_X_y
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\sklearn\utils\__init__.py:28, in <module>
#      26 from ..exceptions import DataConversionWarning
#      27 from .deprecation import deprecated
# ---> 28 from .fixes import np_version, parse_version
#      29 from ._estimator_html_repr import estimator_html_repr
#      30 from .validation import (
#      31     as_float_array,
#      32     assert_all_finite,
#    (...)
#      40     check_scalar,
#      41 )
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\sklearn\utils\fixes.py:20, in <module>
#      18 import scipy.sparse as sp
#      19 import scipy
# ---> 20 import scipy.stats
#      21 from scipy.sparse.linalg import lsqr as sparse_lsqr  # noqa
#      22 import threadpoolctl
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\stats\__init__.py:441, in <module>
#       1 """
#       2 .. _statsrefmanual:
#       3
#    (...)
#     438
#     439 """
# --> 441 from .stats import *
#     442 from .distributions import *
#     443 from .morestats import *
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\stats\stats.py:43, in <module>
#      41 import scipy.special as special
#      42 from scipy import linalg
# ---> 43 from . import distributions
#      44 from . import mstats_basic
#      45 from ._stats_mstats_common import (_find_repeats, linregress, theilslopes,
#      46                                    siegelslopes)
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\stats\distributions.py:8, in <module>
#       1 #
#       2 # Author:  Travis Oliphant  2002-2011 with contributions from
#       3 #          SciPy Developers 2004-2011
#    (...)
#       6 #       instead of `git blame -Lxxx,+x`.
#       7 #
# ----> 8 from ._distn_infrastructure import (rv_discrete, rv_continuous, rv_frozen)
#      10 from . import _continuous_distns
#      11 from . import _discrete_distns
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:24, in <module>
#      20 from scipy.special import (comb, chndtr, entr, xlogy, ive)
#      22 # for root finding for continuous distribution ppf, and max likelihood
#      23 # estimation
# ---> 24 from scipy import optimize
#      26 # for functions of continuous distributions (e.g. moments, entropy, cdf)
#      27 from scipy import integrate
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\optimize\__init__.py:401, in <module>
#       1 """
#       2 =====================================================
#       3 Optimization and root finding (:mod:`scipy.optimize`)
#    (...)
#     397 :mod:`Additional information on the nonlinear solvers <scipy.optimize.nonlin>`
#     398 """
#     400 from .optimize import *
# --> 401 from ._minimize import *
#     402 from ._root import *
#     403 from ._root_scalar import *
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\optimize\_minimize.py:27, in <module>
#      25 from ._trustregion_krylov import _minimize_trust_krylov
#      26 from ._trustregion_exact import _minimize_trustregion_exact
# ---> 27 from ._trustregion_constr import _minimize_trustregion_constr
#      29 # constrained minimization
#      30 from .lbfgsb import _minimize_lbfgsb
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\optimize\_trustregion_constr\__init__.py:4, in <module>
#       1 """This module contains the equality constrained SQP solver."""
# ----> 4 from .minimize_trustregion_constr import _minimize_trustregion_constr
#       6 __all__ = ['_minimize_trustregion_constr']
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\optimize\_trustregion_constr\minimize_trustregion_constr.py:5, in <module>
#       3 from scipy.sparse.linalg import LinearOperator
#       4 from .._differentiable_functions import VectorFunction
# ----> 5 from .._constraints import (
#       6     NonlinearConstraint, LinearConstraint, PreparedConstraint, strict_bounds)
#       7 from .._hessian_update_strategy import BFGS
#       8 from ..optimize import OptimizeResult
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\scipy\optimize\_constraints.py:8, in <module>
#       6 from .optimize import OptimizeWarning
#       7 from warnings import warn
# ----> 8 from numpy.testing import suppress_warnings
#       9 from scipy.sparse import issparse
#      12 def _arr_to_scalar(x):
#      13     # If x is a numpy array, return x.item().  This will
#      14     # fail if the array has more than one element.
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\numpy\testing\__init__.py:11, in <module>
#       8 from unittest import TestCase
#      10 from . import _private
# ---> 11 from ._private.utils import *
#      12 from ._private.utils import (_assert_valid_refcount, _gen_alignment_data)
#      13 from ._private import extbuild, decorators as dec
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\numpy\testing\_private\utils.py:480, in <module>
#     476         pprint.pprint(desired, msg)
#     477         raise AssertionError(msg.getvalue())
# --> 480 @np._no_nep50_warning()
#     481 def assert_almost_equal(actual,desired,decimal=7,err_msg='',verbose=True):
#     482     """
#     483     Raises an AssertionError if two items are not equal up to desired
#     484     precision.
#    (...)
#     548
#     549     """
#     550     __tracebackhide__ = True  # Hide traceback for py.test
#
# File c:\Users\Silvia Grosso\anaconda3\lib\site-packages\numpy\__init__.py:313, in __getattr__(attr)
#     305     raise AttributeError(__former_attrs__[attr])
#     307 # Importing Tester requires importing all of UnitTest which is not a
#     308 # cheap import Since it is mainly used in test suits, we lazy import it
#     309 # here to save on the order of 10 ms of import time for most users
#     310 #
#     311 # The previous way Tester was imported also had a side effect of adding
#     312 # the full `numpy.testing` namespace
# --> 313 if attr == 'testing':
#     314     import numpy.testing as testing
#     315     return testing
#
# AttributeError: module 'numpy' has no attribute '_no_nep50_warning'
